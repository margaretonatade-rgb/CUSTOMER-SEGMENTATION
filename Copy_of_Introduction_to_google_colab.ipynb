# %% [markdown]
# <a href="https://colab.research.google.com/github/margaretonatade-rgb/CUSTOMER-SEGMENTATION/blob/main/Copy_of_Introduction_to_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# My First Code

# %%
print("Nigeria")
# Out:
# Nigeria

# %%
Name = "Margaret"

# %%
print(Name)
# Out:
# Margaret

# %%
Country = "Nigeria"

# %%
print (Country)
# Out:
# Nigeria

# %%
type ("34")
# Out:
# str

# %%
type (34)
# Out:
# int

# %%
type (34.0)
# Out:
# float

# %%
type (True)
# Out:
# bool

# %%
type (False)
# Out:
# bool

# %%
firstnumber = 56

# %%
print(firstnumber)
# Out:
# 56

# %%
firstEvenNumber = 34

# %%
first_even_number =34

# %%
FirstEvenNumber =66

# %%
if,def,with,open
